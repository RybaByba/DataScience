# %% [markdown]
# Task 1:
# - вивести 7 перших рядків
# - вивести загальну інформацію про датасет
# - Середнє значення по BasePay
# - Найбільше OvertimePay у наборі даних
# - Яка робота в  JOSEPH DRISCOLL
# - Скільки заробляє JOSEPH DRISCOLL
# - Хто найбільше заробляє (з премією)
# - Яким був середній  BasePay усіх працівників на рік?
# - Які 5 найпоширеніших робочих місць?
# - Скільки посад у 2013 році представляла лише одна людина?
# - Скільки людей має слово начальник у назві посади?
# - Чи існує взаємозв'язок між довжиною рядка посади та посадовим окладом

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv')

# %%
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=148654, step=1)

# %%
df['Year'] = pd.to_datetime(df['Year'], format="%Y")
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#         Year  Notes         Agency  Status
# ...

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits  Notes  Status
# count  112491.000000  148654.000000     148654.000000    0.0     0.0
# mean    25007.893151   74768.321972      93692.554811    NaN     NaN
# std     15402.215858   50517.005274      62793.533483    NaN     NaN
# min       -33.890000    -618.130000       -618.130000    NaN     NaN
# ...

# %%
df.iloc[0:7]
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6     DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7          ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# ...

# %%
df.shape[0]
# Out:
# 148654

# %%
df['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
max_op = df['OvertimePay'].max()

# %%
df[df['OvertimePay'] == max_op]['EmployeeName']
# Out:
# 1    GARY JIMENEZ
# Name: EmployeeName, dtype: object

# %%
df['New_pay'] = df['BasePay'] * 1.2
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#         Year  Notes         Agency  Status     New_pay
# ...

# %%
def new_salary(old_salary):
    return old_salary * 1.2



df['New_pay2'] = df['BasePay'].map(new_salary)
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#         Year  Notes         Agency  Status     New_pay    New_pay2
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df_1 = df.groupby(['Year'])[['BasePay', 'TotalPay']].mean()
df_1
# Out:
#            BasePay      TotalPay
# Year
# 2011  63595.956517  71744.103871
# 2012  65436.406857  74113.262265
# 2013  69630.030216  77611.443142
# 2014  66564.421924  75463.918140

# %%
df_1.reset_index(inplace=True)

# %%
df_1
# Out:
#    Year       BasePay      TotalPay
# 0  2011  63595.956517  71744.103871
# 1  2012  65436.406857  74113.262265
# 2  2013  69630.030216  77611.443142
# 3  2014  66564.421924  75463.918140

# %%
df_2 = df.groupby(['Year']).agg({'BasePay' : 'mean',
                         'TotalPay' : 'mean'})

# %%
df_2.reset_index()
# Out:
#    Year       BasePay      TotalPay
# 0  2011  63595.956517  71744.103871
# 1  2012  65436.406857  74113.262265
# 2  2013  69630.030216  77611.443142
# 3  2014  66564.421924  75463.918140

# %%
df_2 = df.groupby(['Year']).agg({'BasePay' : ['mean', 'count']})

# %%
df_2['BasePay']
# Out:
#               mean  count
# Year
# 2011  63595.956517  36159
# 2012  65436.406857  36766
# 2013  69630.030216  37001
# 2014  66564.421924  38119

# %%
df['JobTitle'].value_counts()[:5]
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
df_3 = df[df['Year'].dt.year == 2013]

df_3 = df_3.groupby(['JobTitle'])[['EmployeeName']].count().reset_index()

# %%
df_3[df_3['EmployeeName'] == 1].shape[0]
# Out:
# 202

# %%
# df.set_index(df.Id, inplace=True)
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
def contains(el):
    if 'chief' in el.lower():
        return True
    return False

# %%
df['JobTitle'].map(contains).sum()
# Out:
# 627

# %%
df[df['JobTitle'].str.contains('CHIEF', case=False)]
# Out:
#             Id         EmployeeName  \
# 4            5      PATRICK GARDNER
# 5            6       DAVID SULLIVAN
# 6            7            ALSON LEE
# 8            9       MICHAEL MORRIS
# 9           10   JOANNE HAYES-WHITE
# ...        ...                  ...
# 138011  138012     Sharon C Jackson
# 139620  139621          Anita S Lee
# 139709  139710     George D Vaughan
# 140080  140081  Patrick W Gillespie
# 140156  140157  Christopher L Ochoa
#
#                                             JobTitle    BasePay  OvertimePay  \
# 4       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                          ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# 6                 BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.90
# 8                 BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64     86362.68
# 9             CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00         0.00
# ...

# %%
df['Len Job'] = df['JobTitle'].map(lambda el: len(el))


df[['Len Job', 'BasePay']].corr()
# Out:
#           Len Job   BasePay
# Len Job  1.000000 -0.005059
# BasePay -0.005059  1.000000
